# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler

# %%
# %matplotlib inline

# %%
df = pd.read_csv('my_PJME_MW.csv', index_col=[0], parse_dates=[0])

df.head()
# Out:
#                 Time  PJME_MW  year  month  dayofmonth  quarter  dayofyear  \
# Date
# 2002-01-01  01:00:00  30393.0  2002      1           1        1          1
# 2002-01-01  02:00:00  29265.0  2002      1           1        1          1
# 2002-01-01  03:00:00  28357.0  2002      1           1        1          1
# 2002-01-01  04:00:00  27899.0  2002      1           1        1          1
# 2002-01-01  05:00:00  28057.0  2002      1           1        1          1
#
#             weekofyear  dayofweek  hour  is_holiday  is_prev_holiday  \
# Date
# 2002-01-01           1          1     1           1                0
# 2002-01-01           1          1     2           1                0
# 2002-01-01           1          1     3           1                0
# 2002-01-01           1          1     4           1                0
# 2002-01-01           1          1     5           1                0
#
#             is_next_holiday
# Date
# 2002-01-01                0
# ...

# %%
plt.figure(figsize =(20,4))
plt.plot( df.index, df['PJME_MW'], 'b' )
plt.title('Потребление энергии' )
plt.ylabel ( 'МВт' )
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'МВт')

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

# %%
day_df = df.resample('D').mean()

# %%
data_exp_1 = exponential_smoothing(day_df['PJME_MW']  , 0.05)

plt.figure(figsize=(20, 9))
plt.plot(day_df.index[:500], day_df['PJME_MW'].values[:500], '.b',label='исходный ряд')

plt.plot(day_df.index[:500], day_df['PJME_MW'].values[:500] - data_exp_1[:500] , color = 'green', label="без сезона по экспоненциальному сглаживанию");

plt.plot(day_df.index[:500], data_exp_1[:500], color = 'red', label="экспоненциальное сглаживание сезон");

plt.xlabel('time')
plt.ylabel('MW')
plt.legend()
plt.title('PJME_MW')
# Out:
# Text(0.5, 1.0, 'PJME_MW')

# %%
new_df = pd.DataFrame(data=data_exp_1, index=day_df.index)
new_df.head()
new_df['t'] = 0
new_df.iloc[1:,1]=new_df.iloc[:-1,0].values
new_df['t1']=0
new_df.iloc[2:,2]=new_df.iloc[:-2,0].values
new_df['t2']=0
new_df.iloc[3:,3]=new_df.iloc[:-3,0].values
new_df.fillna(0)

new_df.head()
# Out:
#                        0             t            t1            t2
# Date
# 2002-01-01  31080.739130      0.000000      0.000000      0.000000
# 2002-01-02  31239.779257  31080.739130      0.000000      0.000000
# 2002-01-03  31403.384044  31239.779257  31080.739130      0.000000
# 2002-01-04  31518.987759  31403.384044  31239.779257  31080.739130
# 2002-01-05  31463.294621  31518.987759  31403.384044  31239.779257

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def split_data(data, split_date):
    return data.loc[data.index.get_level_values('Date') <= split_date].copy(), \
           data.loc[data.index.get_level_values('Date') >  split_date].copy()

# %%
def check_h(model, X_train, y_train, X_test, y_test, h=1):
    model_gb.fit(X_train, y_train) 
    X_test_pred = model_gb.predict(X_test)
    
    plt.figure(figsize=( 20, 4 ))

    plt.xlabel('Время')
    plt.ylabel('Потребление энергии')
    plt.plot(test.index[h:],X_test_pred, label='predict data')
    plt.plot(test.index[h:],y_test, label='test data')
    plt.plot(day_df.loc['11-03-2016':].index, day_df.loc['11-03-2016':]['PJME_MW'], label='исходный ряд')

    plt.legend()

    er_g = mean_absolute_percentage_error(y_true=y_test, y_pred=X_test_pred)

    print('ошибка градиентного бустинга :  ', er_g, '%')

# %%
train, test = split_data(new_df, '10-03-2016')

X_train = train.iloc[:-1,:]
y_train = train[new_df.columns[0]].values[1:]
X_test = test.iloc[:-1,:]
y_test = test[new_df.columns[0]].values[1:]

plt.figure( figsize=( 15, 7 ))
plt.xlabel('Время')
plt.ylabel('Потребление энергии')
plt.plot(train.index.get_level_values('Date'),train[new_df.columns[0]], label='train data' )
plt.plot(test.index.get_level_values('Date'),test[new_df.columns[0]], label='test data')
plt.title('Тестовые и тренировочные данные')
plt.legend()

# %%
model_gb = GradientBoostingRegressor(max_depth=15, random_state=0, n_estimators=100)

# %%
check_h(model_gb, X_train, y_train, X_test, y_test, 1)
# Out:
# ошибка градиентного бустинга :   0.4167309766169589 %

# %%
X_train = train.iloc[:-10,:]
y_train = train[new_df.columns[0]].values[10:]
X_test = test.iloc[:-10,:]
y_test = test[new_df.columns[0]].values[10:]

plt.figure( figsize=( 15, 7 ))
plt.xlabel('Время')
plt.ylabel('Потребление энергии')
plt.plot(train.index.get_level_values('Date'),train[new_df.columns[0]], label='train data' )
plt.plot(test.index.get_level_values('Date'),test[new_df.columns[0]], label='test data')
plt.title('Тестовые и тренировочные данные')
plt.legend()

# %%
check_h(model_gb, X_train, y_train, X_test, y_test, 10)
# Out:
# ошибка градиентного бустинга :   3.1472545861164423 %

# %% [markdown]
# Ошибка увеличивается с увеличением шага интервала прогноза (идентично Brent, хотя и выглядит лучше)
